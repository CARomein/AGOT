# %%
conda install geopandas

# %%
#https://github.com/geopandas/geopandas/blob/master/doc/source/getting_started/introduction.ipynb

import geopandas

path_to_data = geopandas.datasets.get_path("nybb")
gdf = geopandas.read_file(path_to_data)

gdf
