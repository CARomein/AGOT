# %%
#Transkribusoutput needs to be split into pieces (many laws in one book)
#Exports are possible in various formats,txt and xml

# %%
# Splitting xml https://stackoverflow.com/questions/36155049/splitting-xml-file-into-multiple-at-given-tags/36155439 
# This splitting is based on tags <structure tags> 
# Option 2 https://stackoverflow.com/questions/7336694/how-to-split-an-xml-file-the-simple-way-in-python

# %%
#Split txt file https://www.kite.com/python/answers/how-to-read-a-text-file-into-a-list-in-python
