# %%
import pandas as pd
# Out:
# /Users/marysia/.pyenv/versions/3.8.3/lib/python3.8/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('policey_bern.csv')
df.head()
# Out:
#              LawID  URI LegislatorID  \
# 0  BER.01.001.4968  NaN   BER.01.001
# 1  BER.01.001.0001  NaN   BER.01.001
# 2  BER.01.001.0002  NaN   BER.01.001
# 3  BER.01.001.0003  NaN   BER.01.001
# 4  BER.01.001.0004  NaN   BER.01.001
#
#                                       LegislatorName  LegislatorTitle  \
# 0  Schultheiß und Kleiner und Großer Rat der Stad...              NaN
# 1  Schultheiß und Kleiner und Großer Rat der Stad...              NaN
# 2  Schultheiß und Kleiner und Großer Rat der Stad...              NaN
# 3  Schultheiß und Kleiner und Großer Rat der Stad...              NaN
# 4  Schultheiß und Kleiner und Großer Rat der Stad...              NaN
#
#   LegislatorReligion  LegislatorRuleBegin  LegislatorRuleEnd TerID  \
# 0                 EV                 1528               1798   BER
# 1                 EV                 1528               1798   BER
# 2                 EV                 1528               1798   BER
# 3                 EV                 1528               1798   BER
# 4                 EV                 1528               1798   BER
#
#   TerShortLabel  ...  RelatesTo Publication                      Archive  \
# 0           BER  ...        NaN         NaN        StAB, A I 480, S. 231
# 1           BER  ...        NaN         NaN   StAB, A I 479, fol. 1v-10v
# 2           BER  ...        NaN         NaN  StAB, A I 479, fol. 11r-13v
# 3           BER  ...        NaN         NaN  StAB, A I 479, fol. 13v-14r
# 4           BER  ...        NaN         NaN  StAB, A I 479, fol. 14v-15v
#
#                                                Title Facs URL  \
# 0  Verpott in der Statt Wäldenn khein Holz zefellen.  NaN NaN
# 1                                                NaN  NaN NaN
# 2  Ordnung der Jarzyten unnd Liechternn ouch annd...  NaN NaN
# 3                                                NaN  NaN NaN
# 4                       Erste Ordnung der Fyrtagenn.  NaN NaN
#
#                                              Matters  Dirty  Controlled Links
# 0  (BER.01.001.4968.06412.0,,4.2,Forst- und Boden...    NaN         NaN   NaN
# 1  (BER.01.001.0001.00001.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
# 2  (BER.01.001.0002.00009.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
# 3  (BER.01.001.0003.00010.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
# 4  (BER.01.001.0004.00011.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
#
# [5 rows x 41 columns]

# %%
df.iloc[1]['Matters']
# Out:
# '(BER.01.001.0001.00001.0,,1.1,Religionsangelegenheiten,,Geistlichkeit,,,,,Amtsausübung; Amtsführung; Predigt; Aufsicht; Überwachung; Verhalten; Lebensführung; Verfehlungen; Arbeitsbedingungen; Sakramente,,,,,,),(BER.01.001.0001.00004.0,,1.1,Religionsangelegenheiten,,Kirchenzucht,,,,,Fasten; Toleranz; Messe,,,,,,),(BER.01.001.0001.00002.0,,1.1,Religionsangelegenheiten,,Kirchenorganisation,,,,,Pfarrstellenbesetzung; Abgaben; Vermögen; Stiftungen; Altäre; Kapellen,,,,,,),(BER.01.001.0001.00006.0,,1.1,Religionsangelegenheiten,,Klosterwesen/Orden,,,,,Verbot; Austritt; Bruderschaft,,,,,,),(BER.01.001.0001.00003.0,,1.1,Religionsangelegenheiten,,Konfession,,,,,Angehörige; Ausland; Religionsausübung,,,,,,),(BER.01.001.0001.00008.0,,1.1,Religionsangelegenheiten,,Religiöse Unterweisung,,,,,Predigt; Gottesdienst,,,,,,),(BER.01.001.0001.00007.0,,2.1,Vergnügungen; Öffentliche Leichtfertigkeit,,Zutrinken/Trunksucht,,,,,,,,,,,),(BER.01.001.0001.00005.0,,2.3,Zensur und Buchdruck,,Zensur,,,,,Bilder; Religiös,,,,,,)'

# %%
def extract_id(x): 
    idnum = x[0]
    if idnum[0] == '(':
        idnum = idnum[1:]
    return idnum

def extract_category_num(x):
    return x[2]

def extract_main_categories(x): 
    main = x[3]
    secondary = None
    if x[4] == '': 
        secondary = x[5]
    return main, secondary

def extract_sub_categories(x): 
    splitted = matter.split(',,,,,')

    return splitted[1]

# %%
li = []

for i, row in df.iterrows(): 
    if i != 1:
        continue

    new_row = row.copy()
    matters = row['Matters']
    
    if len(matters) == 0:
        print('this is the case')
    for matter in matters.split('),('):
        if matter == '':
            continue
            
        splitted = matter.split(',')
        
        idnum = extract_id(splitted)
        cat_num = extract_category_num(splitted)
        main, secondary = extract_main_categories(splitted)
        subcategories = extract_sub_categories(matter)
        
        print(matter)
        print(f'\nID: {idnum}')
        print(f'Category number: {cat_num}')
        print(f'Main category: {main} \t Secondary {secondary}')
        print(f'Subcategories: {subcategories} \n\n\n')
        
        
        li.append([row['LawID'], idnum, cat_num, main, secondary, subcategories])
# Out:
# (BER.01.001.0001.00001.0,,1.1,Religionsangelegenheiten,,Geistlichkeit,,,,,Amtsausübung; Amtsführung; Predigt; Aufsicht; Überwachung; Verhalten; Lebensführung; Verfehlungen; Arbeitsbedingungen; Sakramente,,,,,,
#
# ID: BER.01.001.0001.00001.0
# Category number: 1.1
# Main category: Religionsangelegenheiten 	 Secondary Geistlichkeit
# Subcategories: Amtsausübung; Amtsführung; Predigt; Aufsicht; Überwachung; Verhalten; Lebensführung; Verfehlungen; Arbeitsbedingungen; Sakramente
#
#
#
# BER.01.001.0001.00004.0,,1.1,Religionsangelegenheiten,,Kirchenzucht,,,,,Fasten; Toleranz; Messe,,,,,,
#
# ID: BER.01.001.0001.00004.0
# Category number: 1.1
# Main category: Religionsangelegenheiten 	 Secondary Kirchenzucht
# Subcategories: Fasten; Toleranz; Messe
#
#
#
# BER.01.001.0001.00002.0,,1.1,Religionsangelegenheiten,,Kirchenorganisation,,,,,Pfarrstellenbesetzung; Abgaben; Vermögen; Stiftungen; Altäre; Kapellen,,,,,,
#
# ID: BER.01.001.0001.00002.0
# Category number: 1.1
# Main category: Religionsangelegenheiten 	 Secondary Kirchenorganisation
# Subcategories: Pfarrstellenbesetzung; Abgaben; Vermögen; Stiftungen; Altäre; Kapellen
#
#
#
# BER.01.001.0001.00006.0,,1.1,Religionsangelegenheiten,,Klosterwesen/Orden,,,,,Verbot; Austritt; Bruderschaft,,,,,,
#
# ID: BER.01.001.0001.00006.0
# Category number: 1.1
# Main category: Religionsangelegenheiten 	 Secondary Klosterwesen/Orden
# Subcategories: Verbot; Austritt; Bruderschaft
#
#
#
# BER.01.001.0001.00003.0,,1.1,Religionsangelegenheiten,,Konfession,,,,,Angehörige; Ausland; Religionsausübung,,,,,,
#
# ID: BER.01.001.0001.00003.0
# Category number: 1.1
# Main category: Religionsangelegenheiten 	 Secondary Konfession
# Subcategories: Angehörige; Ausland; Religionsausübung
#
#
#
# BER.01.001.0001.00008.0,,1.1,Religionsangelegenheiten,,Religiöse Unterweisung,,,,,Predigt; Gottesdienst,,,,,,
#
# ID: BER.01.001.0001.00008.0
# Category number: 1.1
# Main category: Religionsangelegenheiten 	 Secondary Religiöse Unterweisung
# Subcategories: Predigt; Gottesdienst
#
#
#
# BER.01.001.0001.00007.0,,2.1,Vergnügungen; Öffentliche Leichtfertigkeit,,Zutrinken/Trunksucht,,,,,,,,,,,
#
# ID: BER.01.001.0001.00007.0
# Category number: 2.1
# Main category: Vergnügungen; Öffentliche Leichtfertigkeit 	 Secondary Zutrinken/Trunksucht
# Subcategories:
#
#
#
# BER.01.001.0001.00005.0,,2.3,Zensur und Buchdruck,,Zensur,,,,,Bilder; Religiös,,,,,,)
#
# ID: BER.01.001.0001.00005.0
# Category number: 2.3
# Main category: Zensur und Buchdruck 	 Secondary Zensur
# Subcategories: Bilder; Religiös

# %%
new_df = pd.DataFrame(li, columns = ['LawID', 'SubLawID', 'CategoryNumber', 'MainCategory', 'SecondaryCategory', 'SubCategories'])
new_df.to_csv('bern_test.csv')

# %%
len(new_df)
# Out:
# 7566

# %%
(
    chickweight
    .merge(mean_weight_per_diet, on="diet")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c454f0730977> in <module>
#       1 (
# ----> 2     chickweight
#       3     .merge(mean_weight_per_diet, on="diet")
#       4 )
#
# NameError: name 'chickweight' is not defined

# %%
test = (
    new_df
    .merge(df, on='LawID')
)

# %%
test.head()
# Out:
#              LawID                 SubLawID CategoryNumber  \
# 0  BER.01.001.4968  BER.01.001.4968.06412.0            4.2
# 1  BER.01.001.0001  BER.01.001.0001.00001.0            1.1
# 2  BER.01.001.0001  BER.01.001.0001.00004.0            1.1
# 3  BER.01.001.0001  BER.01.001.0001.00002.0            1.1
# 4  BER.01.001.0001  BER.01.001.0001.00006.0            1.1
#
#                MainCategory    SecondaryCategory  \
# 0   Forst- und Bodennutzung                Forst
# 1  Religionsangelegenheiten        Geistlichkeit
# 2  Religionsangelegenheiten         Kirchenzucht
# 3  Religionsangelegenheiten  Kirchenorganisation
# 4  Religionsangelegenheiten   Klosterwesen/Orden
#
#                                        SubCategories  URI LegislatorID  \
# 0                     Forstfrevel,Kein näheres Datum  NaN   BER.01.001
# 1  Amtsausübung; Amtsführung; Predigt; Aufsicht; ...  NaN   BER.01.001
# 2                            Fasten; Toleranz; Messe  NaN   BER.01.001
# 3  Pfarrstellenbesetzung; Abgaben; Vermögen; Stif...  NaN   BER.01.001
# 4                     Verbot; Austritt; Bruderschaft  NaN   BER.01.001
#
#                                       LegislatorName  LegislatorTitle  ...  \
# 0  Schultheiß und Kleiner und Großer Rat der Stad...              NaN  ...
# 1  Schultheiß und Kleiner und Großer Rat der Stad...              NaN  ...
# 2  Schultheiß und Kleiner und Großer Rat der Stad...              NaN  ...
# 3  Schultheiß und Kleiner und Großer Rat der Stad...              NaN  ...
# 4  Schultheiß und Kleiner und Großer Rat der Stad...              NaN  ...
#
#   RelatesTo  Publication                     Archive  \
# 0       NaN          NaN       StAB, A I 480, S. 231
# 1       NaN          NaN  StAB, A I 479, fol. 1v-10v
# 2       NaN          NaN  StAB, A I 479, fol. 1v-10v
# 3       NaN          NaN  StAB, A I 479, fol. 1v-10v
# 4       NaN          NaN  StAB, A I 479, fol. 1v-10v
#
#                                                Title Facs  URL  \
# 0  Verpott in der Statt Wäldenn khein Holz zefellen.  NaN  NaN
# 1                                                NaN  NaN  NaN
# 2                                                NaN  NaN  NaN
# 3                                                NaN  NaN  NaN
# 4                                                NaN  NaN  NaN
#
#                                              Matters  Dirty  Controlled Links
# 0  (BER.01.001.4968.06412.0,,4.2,Forst- und Boden...    NaN         NaN   NaN
# 1  (BER.01.001.0001.00001.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
# 2  (BER.01.001.0001.00001.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
# 3  (BER.01.001.0001.00001.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
# 4  (BER.01.001.0001.00001.0,,1.1,Religionsangeleg...    NaN         NaN   NaN
#
# [5 rows x 46 columns]

# %%
len(df)
# Out:
# 4932

# %%
len(df['LawID'].unique())
# Out:
# 4932

# %%
len(new_df['LawID'].unique())
# Out:
# 4932

# %%
len(test['LawID'].unique())
# Out:
# 4932

# %%
test.to_csv('data_with_matters.csv', index=False)

# %%
(
    new_df
    .loc[lambda df: df['MainCategory'] == 'Religionsangelegenheiten']
    ['SecondaryCategory'].value_counts()
)

# %%
(
    new_df
#     .loc[lambda df: df['SubCategories'].contains('Wirte')]
)

# %%
(
    new_df
    .loc[new_df['SubCategories'].str.contains('Wirte')]
)
# Out:
#                 LawID                 SubLawID CategoryNumber  \
# 231   BER.01.001.0079  BER.01.001.0079.00206.0            2.1
# 232   BER.01.001.0079  BER.01.001.0079.00206.1            2.1
# 240   BER.01.001.0082  BER.01.001.0082.00216.0            2.1
# 439   BER.01.001.0073  BER.01.001.0073.00194.0            4.6
# 528   BER.01.001.0358  BER.01.001.0358.00584.0            4.7
# 1145  BER.01.001.0591  BER.01.001.0591.00888.0            4.6
# 1772  BER.01.001.0981  BER.01.001.0981.01359.0            4.6
# 4520  BER.01.001.4182  BER.01.001.4182.05348.0            4.6
# 6087  BER.01.001.3878  BER.01.001.3878.04956.0            4.6
# 6627  BER.01.001.4202  BER.01.001.4202.05388.0            2.1
# 6672  BER.01.001.4237  BER.01.001.4237.05425.0            4.6
# 6676  BER.01.001.4241  BER.01.001.4241.05429.0            4.6
# 6810  BER.01.001.4289  BER.01.001.4289.05494.0            4.6
# 6811  BER.01.001.4289  BER.01.001.4289.05494.1            4.6
# 7223  BER.01.001.4612  BER.01.001.4612.05905.0            5.4
#
#                                     MainCategory        SecondaryCategory  \
# 231   Vergnügungen; Öffentliche Leichtfertigkeit  Müßiggang/Verschwendung
# 232   Vergnügungen; Öffentliche Leichtfertigkeit     Zutrinken/Trunksucht
# 240   Vergnügungen; Öffentliche Leichtfertigkeit  Müßiggang/Verschwendung
# 439                  Handel und Dienstleistungen    Bewirtung/Gaststätten
# 528                        Geld- und Kreditwesen        Konkurs/Bankbruch
# 1145                 Handel und Dienstleistungen    Bewirtung/Gaststätten
# 1772                 Handel und Dienstleistungen       Handelsbedingungen
# 4520                 Handel und Dienstleistungen    Bewirtung/Gaststätten
# 6087                 Handel und Dienstleistungen       Handelsbedingungen
# 6627  Vergnügungen; Öffentliche Leichtfertigkeit              Glücksspiel
# 6672                 Handel und Dienstleistungen    Bewirtung/Gaststätten
# 6676                 Handel und Dienstleistungen    Bewirtung/Gaststätten
# 6810                 Handel und Dienstleistungen       Handelsbedingungen
# 6811                 Handel und Dienstleistungen                    Zölle
# 7223                  Bauwesen und Infrastruktur             Feuerpolizei
#
#                                           SubCategories
# 231             Gaststättenbesuch; Wirte; Verantwortung
# 232             Gaststättenbesuch; Wirte; Verantwortung
# 240                            Gaststättenbesuch; Wirte
# 439                                 Wirte; Wein; Erwerb
# 528                 Betrug; Ausweisung; Anspruch; Wirte
# 1145                           Eidespflicht; Wirte; Eid
# 1772                    Wein; Wirte; Ausschank; Verkauf
# 4520  Unterkunft; Berufspflichten; Wirte; Obhut; Fuh...
# 6087           Binnenhandel; Stadt; Wein; Säumer; Wirte
# 6627  Aufsicht; Überwachung; Wirte,,,Erläuterung StA...
# 6672  Weinausschank; Branntwein; Ausschank; Wirte; E...
# 6676           Berufspflichten; Wirte; Obhut; Fuhrwerke
# 6810  Einfuhr; Warenmengen; Warenkennzeichnung; Wein...
# 6811  Einfuhr; Warenmengen; Warenkennzeichnung; Wein...
# 7223  Aufsicht; Bauvorschriften; Feuerstätten; Dachm...
